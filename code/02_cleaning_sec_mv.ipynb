# %% [markdown]
# # [Cleaning: SEC dataset, Sector Market Value](#section-title)

# %%
#imports
import pandas as pd
from polygon import RESTClient
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ---

# %% [markdown]
# ## Importing and Consolidationg of past datasets and SEC Dataset:
# - The purpose of including the SEC dataset was to obtain a unique identifier (known as the CIK) for each company and reference this across all datasets to ensure I am identifying and matching companies correctly.
#
# - The GICS dataframe identifies companies by stock ticker and company name, the latter of which can vary by records. For example, "Apple" and "Apple Inc." refer to the same company. To avoid misidentifying identical companies based on name variations, I have amended the GICS dataframe to include each company's CIK identifier, per the __[SEC's database Edgar](https://www.sec.gov/include/ticker.txt)__ .
#
#
# - CIK, or __[Central Index Key](https://www.sec.gov/edgar/searchedgar/cik)__, is a unique identifier for each exchange-traded stock. Within the context of this project, this key is useful to map companies in the GICS dataframe to this unique code. The CIK is also used by the financial statement API employed below, so encorporatingthe CIK into the GICS dataframe allows for a similar column by which to join the dataframes after calling and cleaning all data.

# %%
# Importing the dataframe for ticker to Cik conversion

df_g = pd.read_csv("../data/cleaned_csvs_interim_steps/gics_cleaned.csv")
df_sec = pd.read_csv("../data/sec_ciks.csv")

df_tickers_list = pd.read_csv("../data/cleaned_csvs_interim_steps/tickers_list.csv")
tickers = df_tickers_list["symbol"].tolist()

# %%
tickers
# Out:
# ['CTVA',
#  'NTR',
#  'FMC',
#  'MOS',
#  'CF',
#  'ICL',
#  'SMG',
#  'UAN',
#  'AVD',
#  'BIOX',
#  'IPI',
#  'MBII',
#  'RKDA',
#  'CGA',
#  'SEED',
#  'YTEN',
#  'SVFD',
#  'RYAAY',
#  'DAL',
#  'LUV',
#  'UAL',
#  'AAL',
#  'ALK',
#  'ZNH',
#  'CPA',
#  'JBLU',
#  'CEA',
#  'ULCC',
#  'SAVE',
#  'ALGT',
#  'SNCY',
#  'VLRS',
#  'SKYW',
#  'HA',
#  'GOL',
#  'MESA',
#  'AER',
#  'ASR',
#  'PAC',
#  'OMAB',
#  'JOBY',
#  'AAWW',
#  'CAAP',
#  'ASLE',
#  'MIC',
#  'BLDE',
#  'UP',
#  'AA',
#  'CSTM',
#  'ACH',
#  'KALU',
#  'CENX',
#  'VFC',
#  'RL',
#  'GIL',
#  'CPRI',
#  'COLM',
#  'PVH',
#  'UA',
#  'UAA',
#  'ZGN',
#  'KTB',
#  'OXM',
#  'HBI',
#  'LEVI',
#  'GOOS',
#  'FIGS',
#  'SGC',
#  'LAKE',
#  'VNCE',
#  'DLA',
#  'JRSH',
#  'EVK',
#  'XELB',
#  'LLL',
#  'TJX',
#  'LULU',
#  'ROST',
#  'BURL',
#  'ONON',
#  'GPS',
#  'CRI',
#  'AEO',
#  'VSCO',
#  'URBN',
#  'BOOT',
#  'BKE',
#  'ANF',
#  'GES',
#  'CHS',
#  'GIII',
#  'SCVL',
#  'DBI',
#  'PLCE',
#  'GCO',
#  'ZUMZ',
#  'DXLG',
#  'CURV',
#  'JILL',
#  'DLTH',
#  'BIRD',
#  'CATO',
#  'RENT',
#  'TLYS',
#  'CTRN',
#  'LVLU',
#  'EXPR',
#  'DBGI',
#  'BLK',
#  'BX',
#  'KKR',
#  'BK',
#  'APO',
#  'AMP',
#  'STT',
#  'TROW',
#  'NTRS',
#  'ARES',
#  'BEN',
#  'BAM',
#  'CG',
#  'GRAB',
#  'SEIC',
#  'IVZ',
#  'AMG',
#  'OWL',
#  'BIPC',
#  'ATCO',
#  'JHG',
#  'AB',
#  'FHI',
#  'CNS',
#  'JXN',
#  'HLNE',
#  'AMK',
#  'CIXX',
#  'APAM',
#  'TPG',
#  'VCTR',
#  'BUR',
#  'STEP',
#  'BCOR',
#  'BBUC',
#  'VRTS',
#  'NOAH',
#  'SII',
#  'BSIG',
#  'PAX',
#  'WETF',
#  'DHIL',
#  'PUYI',
#  'PX',
#  'VINP',
#  'MSB',
#  'GCMG',
#  'MN',
#  'SWKH',
#  'SCU',
#  'HYW',
#  'PZN',
#  'SAMG',
#  'AAMC',
#  'MGLD',
#  'HNNA',
#  'AINC',
#  'DXR',
#  'GROW',
#  'SFE',
#  'MTR',
#  'JP',
#  'LGHL',
#  'PHCF',
#  'PAG',
#  'KMX',
#  'AN',
#  'LAD',
#  'DRVN',
#  'ABG',
#  'GPI',
#  'RUSHA',
#  'RUSHB',
#  'CARS',
#  'SAH',
#  'CRMT',
#  'KFS',
#  'LAZY',
#  'VRM',
#  'RMBL',
#  'KXIN',
#  'LOTZ',
#  'LMPX',
#  'RENN',
#  'JZXN',
#  'TSLA',
#  'TM',
#  'RACE',
#  'GM',
#  'HMC',
#  'F',
#  'STLA',
#  'LI',
#  'TTM',
#  'LCID',
#  'NIO',
#  'RIVN',
#  'XPEV',
#  'FSR',
#  'NKLA',
#  'BLBD',
#  'HYLN',
#  'PTRA',
#  'FFIE',
#  'NIU',
#  'GOEV',
#  'HYZN',
#  'MULN',
#  'WKHS',
#  'RIDE',
#  'ARVL',
#  'CENN',
#  'ELMS',
#  'SOLO',
#  'GP',
#  'VEV',
#  'SEV',
#  'VLCN',
#  'AYRO',
#  'APTV',
#  'MGA',
#  'LKQ',
#  'BWA',
#  'LEA',
#  'ALV',
#  'GNTX',
#  'VC',
#  'ALSN',
#  'ADNT',
#  'GT',
#  'QS',
#  'MTOR',
#  'DORM',
#  'DAN',
#  'THRM',
#  'XPEL',
#  'TEN',
#  'MNRO',
#  'MOD',
#  'SES',
#  'AXL',
#  'GGR',
#  'SMP',
#  'PLOW',
#  'ALLG',
#  'INVZ',
#  'SRI',
#  'GTX',
#  'MLR',
#  'AEVA',
#  'HLLY',
#  'CPS',
#  'CVGI',
#  'KNDI',
#  'XL',
#  'CAAS',
#  'SUP',
#  'WPRT',
#  'MPAA',
#  'STRT',
#  'RMO',
#  'LIDR',
#  'HZN',
#  'SYPR',
#  'FRSX',
#  'WKSP',
#  'UFAB',
#  'HDB',
#  'IBN',
#  'USB',
#  'PNC',
#  'TFC',
#  'LYG',
#  'MFG',
#  'BBD',
#  'BBDO',
#  'ITUB',
#  'DB',
#  'MTB',
#  'FITB',
#  'RF',
#  'HBAN',
#  'KB',
#  'CFG',
#  'SHG',
#  'BAP',
#  'KEY',
#  'BCH',
#  'FHN',
#  'BSAC',
#  'FCNCA',
#  'CBSH',
#  'BSBR',
#  'WBS',
#  'CFR',
#  'SIVB',
#  'WF',
#  'NYCB',
#  'PB',
#  'BOKF',
#  'SSB',
#  'CMA',
#  'UBSI',
#  'GBCI',
#  'VLY',
#  'FFIN',
#  'HOMB',
#  'BSMX',
#  'WTFC',
#  'SBNY',
#  'SNV',
#  'ONB',
#  'ZION',
#  'FNB',
#  'PNFP',
#  'OZK',
#  'BPOP',
#  'UMPQ',
#  'TFSL',
#  'WAL',
#  'UCBI',
#  'HWC',
#  'FIBK',
#  'INDB',
#  'SFBS',
#  'UMBF',
#  'CBU',
#  'BANF',
#  'ASB',
#  'IFS',
#  'FHB',
#  'IBOC',
#  'CIB',
#  'AUB',
#  'ABCB',
#  'CATY',
#  'CVBF',
#  'TCBI',
#  'FULT',
#  'WSFS',
#  'ITCB',
#  'FRC',
#  'PPBI',
#  'SFNC',
#  'AX',
#  'FFBC',
#  'EBC',
#  'CADE',
#  'SBCF',
#  'FBC',
#  'BOH',
#  'FBP',
#  'FRME',
#  'CLBK',
#  'PRK',
#  'WAFD',
#  'HTH',
#  'WSBC',
#  'IBTX',
#  'BANR',
#  'RNST',
#  'EFSC',
#  'LKFN',
#  'BKU',
#  'HTLF',
#  'COLB',
#  'NWBI',
#  'TBBK',
#  'SYBT',
#  'TBK',
#  'TRMK',
#  'NBTB',
#  'FBNC',
#  'PFS',
#  'FBK',
#  'TCBK',
#  'TOWN',
#  'CHCO',
#  'FCF',
#  'GGAL',
#  'STBA',
#  'WABC',
#  'NBHC',
#  'OFG',
#  'HOPE',
#  'SASR',
#  'CASH',
#  'MBIN',
#  'BUSE',
#  'SRCE',
#  'BHLB',
#  'PACW',
#  'OCFC',
#  'LOB',
#  'BMA',
#  'SBSI',
#  'EGBN',
#  'LBAI',
#  'VBTX',
#  'NCBS',
#  'OBNK',
#  'TSC',
#  'GABC',
#  'CFFN',
#  'TMP',
#  'NIC',
#  'BRKL',
#  'DCOM',
#  'AVAL',
#  'BY',
#  'BBAR',
#  'ABTX',
#  'FBMS',
#  'BFC',
#  'HFWA',
#  'AMTB',
#  'PEBO',
#  'PFC',
#  'QCRH',
#  'CBTX',
#  'BANC',
#  'PFBC',
#  'RBCAA',
#  'UVSP',
#  'CTBI',
#  'CNOB',
#  'GSBC',
#  'HBT',
#  'OSBC',
#  'TRST',
#  'WASH',
#  'HONE',
#  'HAFC',
#  'NFBK',
#  'AMAL',
#  'KRNY',
#  'CUBI',
#  'FMBH',
#  'CFB',
#  'CAC',
#  'PGC',
#  'HTBK',
#  'CATC',
#  'CCBG',
#  'CPF',
#  'MBWM',
#  'CCB',
#  'HIFS',
#  'MSBI',
#  'FMNB',
#  'LBC',
#  'BLX',
#  'HBNC',
#  'THFF',
#  'HTBI',
#  'SMBC',
#  'FCBC',
#  'BFST',
#  'FFIC',
#  'AROW',
#  'MPB',
#  'MCBS',
#  'CCNE',
#  'BHB',
#  'SMBK',
#  'FFWM',
#  'GCBC',
#  'MCB',
#  'EBTC',
#  'EQBK',
#  'SPFI',
#  'BMRC',
#  'MOFG',
#  'IBCP',
#  'MCBC',
#  'GNTY',
#  'RRBI',
#  'AMNB',
#  'FMAO',
#  'CARE',
#  'WSBF',
#  'FSBC',
#  'CZNC',
#  'ALRS',
#  'HMST',
#  'NBN',
#  'CZFS',
#  'CSTR',
#  'FLIC',
#  'JMSB',
#  'PFIS',
#  'BWB',
#  'WTBA',
#  'PFHD',
#  'RBB',
#  'SBT',
#  'ESQ',
#  'FISI',
#  'FNLC',
#  'HBCP',
#  'SHBI',
#  'PCSB',
#  'CIVB',
#  'ACNB',
#  'OBT',
#  'SMMF',
#  'FDBC',
#  'MVBF',
#  'BSRR',
#  'NRIM',
#  'SFST',
#  'PBFS',
#  'BLFY',
#  'FBIZ',
#  'CVCY',
#  'UNTY',
#  'NWFL',
#  'FRST',
#  'CBNK',
#  'BCML',
#  'TSBK',
#  'FSBW',
#  'BCBP',
#  'TCBX',
#  'USCB',
#  'MBCN',
#  'ORRF',
#  'BSVN',
#  'PKBK',
#  'NECB',
#  'SSBK',
#  'CVLY',
#  'CHMG',
#  'PCB',
#  'NKSH',
#  'VABK',
#  'PLBC',
#  'OVLY',
#  'COFS',
#  'BWFG',
#  'VBNK',
#  'TCFC',
#  'BRBS',
#  'PDLB',
#  'CFFI',
#  'LCNB',
#  'EVBN',
#  'ATLO',
#  'WNEB',
#  'BPRN',
#  'MYFW',
#  'MNSB',
#  'PEBK',
#  'CBAN',
#  'FGBI',
#  'SUPV',
#  'TBNK',
#  'CALB',
#  'WMPN',
#  'FVCB',
#  'ESSA',
#  'PWOD',
#  'INBK',
#  'HWBK',
#  'MRBK',
#  'FCCO',
#  'ISTR',
#  'LMST',
#  'BSBK',
#  'SAL',
#  'OPBK',
#  'FRAF',
#  'RNDB',
#  'HNVR',
#  'FNWD',
#  'PTRS',
#  'PVBC',
#  'FFNW',
#  'FNCB',
#  'EBMT',
#  'FRBA',
#  'FINW',
#  'MLVF',
#  'PBIP',
#  'RMBI',
#  'OFED',
#  'CZWI',
#  'FUNC',
#  'OPOF',
#  'FSFG',
#  'RVSB',
#  'OVBC',
#  'BFIN',
#  'FNWB',
#  'CWBC',
#  'CBFV',
#  'UBFO',
#  'LARK',
#  'CFBK',
#  'UBOH',
#  'UNB',
#  'FXNC',
#  'SFBC',
#  'PROV',
#  'SBFG',
#  'AFBI',
#  'RBKB',
#  'EMCF',
#  'UBCP',
#  'BKSC',
#  'HMNF',
#  'CULL',
#  'PBHC',
#  'AUBN',
#  'VBFC',
#  'FCAP',
#  'FRBK',
#  'MGYR',
#  'TCBC',
#  'BAFN',
#  'CIZN',
#  'SSBI',
#  'FSEA',
#  'FFBW',
#  'HVBC',
#  'CLST',
#  'ASRV',
#  'LSBK',
#  'BCOW',
#  'CFSB',
#  'BYFC',
#  'IROQ',
#  'HFBL',
#  'BOTJ',
#  'KFFB',
#  'NSTS',
#  'TCBS',
#  'CNNB',
#  'FUSB',
#  'PBBK',
#  'SI',
#  'PNBK',
#  'MSVB',
#  'WVFC',
#  'OPHC',
#  'GBNY',
#  'GLBZ',
#  'CARV',
#  'JPM',
#  'BAC',
#  'WFC',
#  'HSBC',
#  'RY',
#  'TD',
#  'C',
#  'MUFG',
#  'UBS',
#  'BMO',
#  'SAN',
#  'BNS',
#  'SMFG',
#  'ING',
#  'BBVA',
#  'CM',
#  'NWG',
#  'BCS',
#  'NU',
#  'EWBC',
#  'CS',
#  'NTB',
#  'BUD',
#  'ABEV',
#  'FMX',
#  'TAP',
#  'TAP.A',
#  'SAM',
#  'CCU',
#  'SBEV',
#  'KO',
#  'PEP',
#  'MNST',
#  'KDP',
#  'CCEP',
#  'CELH',
#  'FIZZ',
#  'COKE',
#  'KOF',
#  'PRMW',
#  'AKO.A',
#  'AKO.B',
#  'OTLY',
#  'COCO',
#  'ZVIA',
#  'NBEV',
#  'REED',
#  'WTER',
#  'BRFH',
#  'DEO',
#  'STZ.B',
#  'STZ',
#  'BF.A',
#  'BF.B',
#  'NAPA',
#  'VWE',
#  'WVVI',
#  'VINE',
#  'EAST',
#  'WBEV',
#  'NVO',
#  'REGN',
#  'VRTX',
#  'SGEN',
#  'BNTX',
#  'GMAB',
#  'ALNY',
#  'BGNE',
#  'ARGX',
#  'BMRN',
#  'INCY',
#  'RPRX',
#  'TECH',
#  'SRPT',
#  'UTHR',
#  'NBIX',
#  'JAZZ',
#  'APLS',
#  'LEGN',
#  'KRTX',
#  'ASND',
#  'EXEL',
#  'ROIV',
#  'RXDX',
#  'IONS',
#  'HALO',
#  'ITCI',
#  'ALKS',
#  'MDGL',
#  'CERT',
#  'CERE',
#  'PTCT',
#  'CRSP',
#  'NTLA',
#  'ISEE',
#  'CYTK',
#  'FOLD',
#  'DNLI',
#  'ZLAB',
#  'PCVX',
#  'ABCM',
#  'VIR',
#  'ACAD',
#  'RETA',
#  'AXSM',
#  'MYOV',
#  'BPMC',
#  'RVNC',
#  'RARE',
#  'ARWR',
#  'SAGE',
#  'PRTA',
#  'HRMY',
#  'GLPG',
#  'HCM',
#  'CORT',
#  'MRTX',
#  'INSM',
#  'BEAM',
#  'TGTX',
#  'IMCR',
#  'XENE',
#  'ABCL',
#  'PRVB',
#  'VTYX',
#  'BBIO',
#  'IMVT',
#  'AMLX',
#  'DNA',
#  'KRYS',
#  'RVMD',
#  'RLAY',
#  'AKRO',
#  'TPTX',
#  'MRVI',
#  'GBT',
#  'FGEN',
#  'CPRX',
#  'XNCR',
#  'CLDX',
#  'SWTX',
#  'VCYT',
#  'KYMR',
#  'CCXI',
#  'PLRX',
#  'BCRX',
#  'MORF',
#  'SNDX',
#  'KDNY',
#  'CVAC',
#  'NUVL',
#  'RNA',
#  'ARVN',
#  'VCEL',
#  'RCKT',
#  'SRRA',
#  'AUPH',
#  'TVTX',
#  'IOVA',
#  'DICE',
#  'DVAX',
#  'RXRX',
#  'ACLX',
#  'AGIO',
#  'DAWN',
#  'KROS',
#  'RCUS',
#  'SMMT',
#  'LGND',
#  'GERN',
#  'DCPH',
#  'ADPT',
#  'REPL',
#  'CDMO',
#  'VRDN',
#  'PTGX',
#  'MNKD',
#  'ZNTL',
#  'VRNA',
#  'SAVA',
#  'RYTM',
#  'BLU',
#  'ORTX',
#  'QURE',
#  'BHVN',
#  'INBX',
#  'MRUS',
#  'VERV',
#  'ETNB',
#  'EQRX',
#  'MIRM',
#  'RGNX',
#  'MLTX',
#  'GMTX',
#  'CRNX',
#  'IMGN',
#  'EXAI',
#  'KURA',
#  'ARDX',
#  'ENTA',
#  'PRTC',
#  'INVA',
#  'CBAY',
#  'VALN',
#  'PHAR',
#  'ALLO',
#  'VKTX',
#  'MCRB',
#  'PNT',
#  'COGT',
#  'IDYA',
#  'AVXL',
#  'BLTE',
#  'ARQT',
#  'TYRA',
#  'TBPH',
#  'CINC',
#  'SVA',
#  'BIOR',
#  'IBRX',
#  'DYN',
#  'SANA',
#  'RAPT',
#  'SRNE',
#  'ADMA',
#  'ANAB',
#  'HLVX',
#  'FDMT',
#  'ICPT',
#  'CTIC',
#  'ACRS',
#  'MOR',
#  'TRDA',
#  'ALDX',
#  'BTAI',
#  'AVTE',
#  'ADGI',
#  'ZYME',
#  'CNCE',
#  'IMTX',
#  'FATE',
#  'EDIT',
#  'ZEAL',
#  'VECT',
#  'LYEL',
#  'CERS',
#  'NVAX',
#  'ALEC',
#  'AGEN',
#  'ABUS',
#  'JANX',
#  'IMGO',
#  'CHRS',
#  'ITOS',
#  'IGMS',
#  'BMEA',
#  'MESO',
#  'MRSN',
#  'ALBO',
#  'TERN',
#  'SRRK',
#  'LQDA',
#  'BCYC',
#  'MGNX',
#  'EWTX',
#  'LXRX',
#  'NRIX',
#  'RPTX',
#  'CGEM',
#  'ANIK',
#  'VIGL',
#  'ALLK',
#  'NSTG',
#  'ARCT',
#  'SIGA',
#  'CMPX',
#  'ATHX',
#  'PEPG',
#  'KNSA',
#  'AURA',
#  'ALVR',
#  'OCUL',
#  'CLBS',
#  'VNDA',
#  'KPTI',
#  'NUVB',
#  'BLUE',
#  'GHRS',
#  'TNGX',
#  'CMMB',
#  'STOK',
#  'DSGN',
#  'GLUE',
#  'ERAS',
#  'CNTA',
#  'AMAM',
#  'VOR',
#  'THRX',
#  'WVE',
#  'OGEN',
#  'TARS',
#  'VYGR',
#  'AUTL',
#  'NGM',
#  'ATXS',
#  'HUMA',
#  'PSTX',
#  'RAIN',
#  'OMGA',
#  'SCPH',
#  'PRLD',
#  'CKPT',
#  'MRNS',
#  'DBVT',
#  'FMTX',
#  'NAUT',
#  'TMBR',
#  'GBIO',
#  'MIGI',
#  'BIVI',
#  'SGMO',
#  'IMRX',
#  'ATRA',
#  'ELOX',
#  'CARA',
#  'STRO',
#  'SLN',
#  'IMAB',
#  'KNTE',
#  'OTLK',
#  'PHAT',
#  'CRBU',
#  'VRCA',
#  'KOD',
#  'FUSN',
#  'CDXS',
#  'AVIR',
#  'APRE',
#  'ACET',
#  'MGTX',
#  'ALPN',
#  'PRQR',
#  'INO',
#  'HRTX',
#  ...]

# %%
print(df_sec.shape)
df_sec.head()
# Out:
# (12084, 2)
#   Unnamed: 0  Unnamed: 1
# 0       aapl      320193
# 1       msft      789019
# 2      brk-b     1067983
# 3        unh      731766
# 4        jnj      200406

# %%
df_sec = df_sec.rename(columns={'Unnamed: 0': 'ticker', 'Unnamed: 1': 'cik'})

# %%
df_sec['cik'].isnull().sum()
# Out:
# 0

# %%
df_sec.duplicated().sum()
# Out:
# 0

# %%
# Save a clean copy of the df_sec as csv, for record
df_sec.to_csv("../data/cleaned_csvs_interim_steps/sec_cleaned.csv", index = False)

# %% [markdown]
# ---

# %% [markdown]
# ## Importing and Consolidationg of Sector Market Value:

# %%
# Importing the sector contribution to total market value df:
df_mv = pd.read_csv("../data/gics_sector_chart.csv", index_col = None)

# %% [markdown]
# ## Deriving Sector Contribution to Total Market Value of US Stock Market
#
# - In order to determine market concentration of each sector and company, I first need to understand the size of the US Financial Markets (in USD) and each sector's contribution to that market.

# %%
# Quick Cleaning:
# Converting columns to lowercase, removing whitespace, removing extraneous symbols
df_mv.columns = df_mv.columns.str.replace(' ', '_')
df_mv.columns = df_mv.columns.str.lower()
df_mv.drop(columns = ["url"], inplace = True)
df_mv.head()
# Out:
#                    sector  sector_revenue_total_(trillions)  \
# 0  Consumer Discretionary                               2.9
# 1        Consumer Staples                               2.6
# 2                  Energy                               2.2
# 3              Financials                               2.7
# 4             Health Care                               2.8
#
#    total_cap_(trillions)
# 0                   46.3
# 1                   46.3
# 2                   46.3
# 3                   46.3
# 4                   46.3

# %%
df_mv.to_csv('../data/cleaned_csvs_interim_steps/mv_cleaned.csv',index=False)

# %% [markdown]
# ---

# %% [markdown]
# ## Concatenating SEC + GICS dataframes, then concatenating (SEC+GICS) + MV

# %%
# Convert the data within the common column to uppercase in both dataframes, per convention, to check for matches

df_sec['ticker'] = df_sec['ticker'].str.upper()
df_g["symbol"] = df_g["symbol"].str.upper()

# %%
# Using an inner join to merge the dataframes df_sec and df_g to df_sec_g
df_sec_g = pd.merge(df_sec, df_g, left_on='ticker', right_on='symbol')

# %%
# Check if all values in the 'ticker' column match the values in the 'symbol' column
all(df_sec_g['ticker'] == df_sec_g['symbol'])
# Out:
# True

# %%
# Check if there are rows where 'ticker' and 'symbol' do not match:

# All rows of 'ticker' and 'symbol' match
df_sec_g.query('ticker != symbol')
# Out:
# Empty DataFrame
# Columns: [ticker, cik, symbol, description, gics_sector, equity_securities, cap_size]
# Index: []

# %% [markdown]
# ### Justification for differences between merged df and df_g count
#
# - Difference in count between merged dataframe and df_g might be explained by companies delisting (buyouts, bankruptcies, etc.) and being updated on the SEC website without being updated on MBA_stocks.com.
#
# 1. MBA website error or sec website error
# 2. lists made at different times, thus recognizing (or not recognizing) bankruptcy, mergers, acquisitions, name changes
# 3. slightly different "universes" of stocks

# %%
df_sec_g.head()
# Out:
#   ticker      cik symbol             description             gics_sector  \
# 0   AAPL   320193   AAPL               Apple Inc  Information Technology
# 1   MSFT   789019   MSFT          Microsoft Corp  Information Technology
# 2    UNH   731766    UNH  Unitedhealth Group Inc             Health Care
# 3    JNJ   200406    JNJ       Johnson & Johnson             Health Care
# 4      V  1403161      V        Visa Inc Class A  Information Technology
#
#   equity_securities   cap_size
# 0     Common stocks  Large cap
# 1     Common stocks  Large cap
# 2     Common stocks  Large cap
# 3     Common stocks  Large cap
# 4     Common stocks  Large cap

# %%
df_sec_g["gics_sector"].unique()
# Out:
# array(['Information Technology', 'Health Care', 'Energy',
#        'Consumer Staples', 'Financials', 'Consumer Discretionary',
#        'Communication Services', 'Utilities', 'Industrials', 'Materials',
#        'Real Estate'], dtype=object)

# %%
df_sec_g
# Out:
#      ticker      cik symbol  \
# 0      AAPL   320193   AAPL
# 1      MSFT   789019   MSFT
# 2       UNH   731766    UNH
# 3       JNJ   200406    JNJ
# 4         V  1403161      V
# ...     ...      ...    ...
# 5983   WLYB   107140   WLYB
# 5984   APTS  1481832   APTS
# 5985  GBBKR  1894951  GBBKR
# 5986  GFGDR  1876714  GFGDR
# 5987  PARAA   813828  PARAA
#
#                                             description  \
# 0                                             Apple Inc
# 1                                        Microsoft Corp
# 2                                Unitedhealth Group Inc
# 3                                     Johnson & Johnson
# 4                                      Visa Inc Class A
# ...                                                 ...
# 5983                    John Wiley & Sons, Inc. Class B
# 5984               Preferred Apartment Communities, Inc
# 5985          Global Blockchain Acquisition Corp. Right
# 5986  The Growth for Good Acquisition Corporation Right
# 5987                         Paramount Global - Class A
#
#                  gics_sector equity_securities   cap_size
# 0     Information Technology     Common stocks  Large cap
# 1     Information Technology     Common stocks  Large cap
# 2                Health Care     Common stocks  Large cap
# 3                Health Care     Common stocks  Large cap
# 4     Information Technology     Common stocks  Large cap
# ...                      ...               ...        ...
# 5983  Communication Services     Common stocks    Mid cap
# 5984             Real Estate             REITs  Small cap
# 5985              Financials     Common stocks  Micro cap
# 5986              Financials     Common stocks  Micro cap
# 5987  Communication Services     Common stocks  Large cap
#
# [5988 rows x 7 columns]

# %%
df_mv["sector"].unique
# Out:
# <bound method Series.unique of 0     Consumer Discretionary
# 1           Consumer Staples
# 2                     Energy
# 3                 Financials
# 4                Health Care
# 5                Industrials
# 6                  Materials
# 7                Real Estate
# 8     Information Technology
# 9     Communication Services
# 10                Uttilities
# Name: sector, dtype: object>

# %%
# Now for the next concatenation:
# Using an inner join to merge the dataframes df_sec and df_g to df_sec_g

df_sec_g_mv = df_sec_g.merge(df_mv, left_on="gics_sector", right_on="sector", how="left")
df_sec_g_mv.drop(columns = ["sector"], inplace = True) # Same as "gics_sector"
df_sec_g_mv.head()
# Out:
#   ticker      cik symbol             description             gics_sector  \
# 0   AAPL   320193   AAPL               Apple Inc  Information Technology
# 1   MSFT   789019   MSFT          Microsoft Corp  Information Technology
# 2    UNH   731766    UNH  Unitedhealth Group Inc             Health Care
# 3    JNJ   200406    JNJ       Johnson & Johnson             Health Care
# 4      V  1403161      V        Visa Inc Class A  Information Technology
#
#   equity_securities   cap_size  sector_revenue_total_(trillions)  \
# 0     Common stocks  Large cap                               5.8
# 1     Common stocks  Large cap                               5.8
# 2     Common stocks  Large cap                               2.8
# 3     Common stocks  Large cap                               2.8
# 4     Common stocks  Large cap                               5.8
#
#    total_cap_(trillions)
# 0                   46.3
# 1                   46.3
# 2                   46.3
# 3                   46.3
# 4                   46.3

# %%
df_sec_g_mv.to_csv('../data/cleaned_csvs_interim_steps/sec_gics_mv_cleaned.csv', index = False)

# %% [markdown]
# ---
